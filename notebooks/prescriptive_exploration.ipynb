# %% [markdown]
# # Prediction Exploration

# %%
import pandas as pd

# %%
features = pd.read_csv("../data/processed/features_pre_race.csv")

# %%
features
# Out:
#       Year                 GrandPrix  ... Driver_enc  Compound_enc
# 0     2018      Abu Dhabi Grand Prix  ...          2             5
# 1     2018      Abu Dhabi Grand Prix  ...          6             6
# 2     2018      Abu Dhabi Grand Prix  ...         10             5
# 3     2018      Abu Dhabi Grand Prix  ...         12             5
# 4     2018      Abu Dhabi Grand Prix  ...         14             5
# ...    ...                       ...  ...        ...           ...
# 3443  2025  United States Grand Prix  ...         33             3
# 3444  2025  United States Grand Prix  ...         34             3
# 3445  2025  United States Grand Prix  ...         37             3
# 3446  2025  United States Grand Prix  ...         38             3
# 3447  2025  United States Grand Prix  ...         40             3
#
# [3448 rows x 17 columns]

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
le = LabelEncoder()
features["TeamName_enc"] = le.fit_transform(features["TeamName"])
features["GrandPrix_enc"] = le.fit_transform(features["GrandPrix"])
features["Driver_enc"] = le.fit_transform(features["Driver"])
features["Compound_enc"] = le.fit_transform(features["Compound"])

# %%
features = features.drop(columns=["GrandPrix", "TeamName", "Driver", "Compound"])

# %%
features
# Out:
#       Year  avg_lap_time   avg_speed  ...  GrandPrix_enc  Driver_enc  Compound_enc
# 0     2018    108.582353  268.205128  ...              1           2             5
# 1     2018    106.669731  276.711111  ...              1           6             6
# 2     2018    112.067381  276.388889  ...              1          10             5
# 3     2018    109.237512  277.219512  ...              1          12             5
# 4     2018    108.354745  274.145833  ...              1          14             5
# ...    ...           ...         ...  ...            ...         ...           ...
# 3443  2025    101.314589  220.187500  ...             40          33             3
# 3444  2025    101.888000  210.600000  ...             40          34             3
# 3445  2025    102.052482  204.096154  ...             40          37             3
# 3446  2025    101.658482  213.490196  ...             40          38             3
# 3447  2025    100.717161  221.288889  ...             40          40             3
#
# [3448 rows x 13 columns]

# %%
scaler = StandardScaler()
X = features.drop(columns=["is_podium"])
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, columns=X.columns)
X = X.drop(columns=["Position"])

y = features["is_podium"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {acc}")
print(f"F1: {f1}")
# Out:
# Accuracy: 0.8830917874396135
# F1: 0.5399239543726235

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[843,  33],
#        [ 88,  71]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       876
#            1       0.68      0.45      0.54       159
#
#     accuracy                           0.88      1035
#    macro avg       0.79      0.70      0.74      1035
# weighted avg       0.87      0.88      0.87      1035

# %%
xgb = XGBClassifier(random_state=42)

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = xgb.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {acc}")
print(f"F1: {f1}")
# Out:
# Accuracy: 0.8801932367149758
# F1: 0.5838926174496645

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[824,  52],
#        [ 72,  87]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       876
#            1       0.63      0.55      0.58       159
#
#     accuracy                           0.88      1035
#    macro avg       0.77      0.74      0.76      1035
# weighted avg       0.87      0.88      0.88      1035
